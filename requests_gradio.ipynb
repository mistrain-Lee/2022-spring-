# %% [markdown]
# <a href="https://colab.research.google.com/github/mistrain-Lee/2022-spring-/blob/main/requests_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api
 # api 란? 
 # 공공 데이터 - 미세먼지 같은 것들, 이런 것들은 땡겨와서 쓸수 있는 것이다. 
 # 프로그램속에 포합할 수 있는 것들을 말한다. api를 가지고 오려면 request를 가지고 온다. 
 # 개발자로서 쓰는 법을 배우겠다. 무료 api가 많다. 공공데이터 포털을 들어간다. https://www.data.go.kr/
 # REST 표준 방법. 프로그램을 할 때의 규악- 이름만 기억ㅎ다. '
 #json- 데이터 포맷, 많이 쓴당. 이것은 무엇이냐? 무료다. 이런 것들 확인할 수 있다. 

 #요청변수. 서비스마다 다를 것이다. 매뉴얼을 보면서 할 것이다. 
 # 그러면 api 서비스에서 출력을 준다.
 #미세먼지- 전체 중ㅇ에서 아에 그대로 파일인 경우도 있다. 우리의 관심사가 아니다. api가 필요함. 
 # 네이버 개발자 센터 - 네이버 공개 api들이 있다. 까까오도 있다.api의 혀앹로 사용한다.

# %%
# !pip install gradio
import gradio as gr
import requests
import pandas as pd

# %%
URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'
      'getCtprvnMesureSidoLIst?'
      'sidoName=서울'
      '&searchCondition=hour'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
response = requests.get(URL)

# 이것이 바로 api이다. 그게 
# 1줄  :url
# 2줄 : 내가 쓰고 자하는 것
# 3줄 기타의 것들. =으로 되어 있는데 각각을 맞추어 써주면 된다. 

# responde 다양한 코드들이 있다. 내용이 어디에 있는가? 
# return xkdlqdl wpdltmsdlek. 제이슨의 결과를 rd에다가 담았다. sidoname서울로 요청했다.

# %% [markdown]
# #### http://jsonviewer.stack.hu/ (copy json here to view json)

# %%
r = response.json()
r
# json 형태이다. 기본적으로 딕트의 형태이다. 
# 얻은 제이슨 responce를 저기 위의 사잍으에 넣는다.
# Out:
# {'response': {'body': {'items': [{'cityName': '강남구',
#      'cityNameEng': 'Gangnam-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '001',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.023',
#      'numOfRows': '10',
#      'o3Value': '0.036',
#      'pageNo': '1',
#      'pm10Value': '32',
#      'pm25Value': '16',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '강동구',
#      'cityNameEng': 'Gangdong-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '002',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.023',
#      'numOfRows': '10',
#      'o3Value': '0.031',
#      'pageNo': '1',
#      'pm10Value': '35',
#      'pm25Value': '20',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '강북구',
#      'cityNameEng': 'Gangbuk-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '003',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.012',
#      'numOfRows': '10',
#      'o3Value': '0.045',
#      'pageNo': '1',
#      'pm10Value': '32',
#      'pm25Value': '18',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.002',
#      'totalCount': ''},
#     {'cityName': '강서구',
#      'cityNameEng': 'Gangseo-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '004',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.021',
#      'numOfRows': '10',
#      'o3Value': '0.041',
#      'pageNo': '1',
#      'pm10Value': '39',
#      'pm25Value': '18',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.005',
#      'totalCount': ''},
#     {'cityName': '관악구',
#      'cityNameEng': 'Gwanak-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '005',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.020',
#      'numOfRows': '10',
#      'o3Value': '0.042',
#      'pageNo': '1',
#      'pm10Value': '30',
#      'pm25Value': '16',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '광진구',
#      'cityNameEng': 'Gwangjin-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '006',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.023',
#      'numOfRows': '10',
#      'o3Value': '0.038',
#      'pageNo': '1',
#      'pm10Value': '35',
#      'pm25Value': '20',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '구로구',
#      'cityNameEng': 'Guro-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '007',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.018',
#      'numOfRows': '10',
#      'o3Value': '0.041',
#      'pageNo': '1',
#      'pm10Value': '32',
#      'pm25Value': '15',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '금천구',
#      'cityNameEng': 'Geumcheon-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '008',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.021',
#      'numOfRows': '10',
#      'o3Value': '0.042',
#      'pageNo': '1',
#      'pm10Value': '28',
#      'pm25Value': '15',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '노원구',
#      'cityNameEng': 'Nowon-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '009',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.020',
#      'numOfRows': '10',
#      'o3Value': '0.044',
#      'pageNo': '1',
#      'pm10Value': '29',
#      'pm25Value': '22',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '도봉구',
#      'cityNameEng': 'Dobong-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '010',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.024',
#      'numOfRows': '10',
#      'o3Value': '0.034',
#      'pageNo': '1',
#      'pm10Value': '30',
#      'pm25Value': '14',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '동대문구',
#      'cityNameEng': 'Dongdaemun-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '011',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.024',
#      'numOfRows': '10',
#      'o3Value': '0.040',
#      'pageNo': '1',
#      'pm10Value': '32',
#      'pm25Value': '17',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '동작구',
#      'cityNameEng': 'Dongjak-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '012',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.018',
#      'numOfRows': '10',
#      'o3Value': '0.044',
#      'pageNo': '1',
#      'pm10Value': '33',
#      'pm25Value': '17',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '마포구',
#      'cityNameEng': 'Mapo-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '013',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.025',
#      'numOfRows': '10',
#      'o3Value': '0.035',
#      'pageNo': '1',
#      'pm10Value': '27',
#      'pm25Value': '13',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '서대문구',
#      'cityNameEng': 'Seodaemun-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '014',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.019',
#      'numOfRows': '10',
#      'o3Value': '0.043',
#      'pageNo': '1',
#      'pm10Value': '36',
#      'pm25Value': '17',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '서초구',
#      'cityNameEng': 'Seocho-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '015',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.022',
#      'numOfRows': '10',
#      'o3Value': '0.037',
#      'pageNo': '1',
#      'pm10Value': '35',
#      'pm25Value': '16',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '성동구',
#      'cityNameEng': 'Seongdong-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '016',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.017',
#      'numOfRows': '10',
#      'o3Value': '0.025',
#      'pageNo': '1',
#      'pm10Value': '38',
#      'pm25Value': '19',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.002',
#      'totalCount': ''},
#     {'cityName': '성북구',
#      'cityNameEng': 'Seongbuk-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '017',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.018',
#      'numOfRows': '10',
#      'o3Value': '0.038',
#      'pageNo': '1',
#      'pm10Value': '36',
#      'pm25Value': '20',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '송파구',
#      'cityNameEng': 'Songpa-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '018',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.024',
#      'numOfRows': '10',
#      'o3Value': '0.036',
#      'pageNo': '1',
#      'pm10Value': '42',
#      'pm25Value': '27',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '양천구',
#      'cityNameEng': 'Yangcheon-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '019',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.020',
#      'numOfRows': '10',
#      'o3Value': '0.038',
#      'pageNo': '1',
#      'pm10Value': '35',
#      'pm25Value': '21',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '영등포구',
#      'cityNameEng': 'Yeongdeungpo-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '020',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '용산구',
#      'cityNameEng': 'Yongsan-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '021',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '은평구',
#      'cityNameEng': 'Eunpyeong-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '022',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.017',
#      'numOfRows': '10',
#      'o3Value': '0.042',
#      'pageNo': '1',
#      'pm10Value': '43',
#      'pm25Value': '30',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '종로구',
#      'cityNameEng': 'Jongno-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '023',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.023',
#      'numOfRows': '10',
#      'o3Value': '0.039',
#      'pageNo': '1',
#      'pm10Value': '33',
#      'pm25Value': '19',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '중구',
#      'cityNameEng': 'Jung-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '024',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.025',
#      'numOfRows': '10',
#      'o3Value': '0.041',
#      'pageNo': '1',
#      'pm10Value': '26',
#      'pm25Value': '19',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.004',
#      'totalCount': ''},
#     {'cityName': '중랑구',
#      'cityNameEng': 'Jungnang-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-23 17:00',
#      'districtCode': '02',
#      'districtNumSeq': '025',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.024',
#      'numOfRows': '10',
#      'o3Value': '0.038',
#      'pageNo': '1',
#      'pm10Value': '33',
#      'pm25Value': '16',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''}],
#    'numOfRows': 100,
#    'pageNo': 1,
#    'totalCount': 25},
#   'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}}}

# %%
items = r['response']['body']['items']
# 리스트로 되어 있다. 

cityName = [item['cityName'] for item in items]
pm10Value = [item['pm10Value'] for item in items]
pm25Value = [item['pm25Value'] for item in items]
so2Value = [item['so2Value'] for item in items]
coValue = [item['coValue'] for item in items]
o3Value = [item['o3Value'] for item in items]
no2Value = [item['no2Value'] for item in items]

pd_cityName = pd.Series(cityName)
pd_pm10Value = pd.Series(pm10Value)   
pd_pm25Value = pd.Series(pm25Value)
so2Value = pd.Series(so2Value)
coValue = pd.Series(coValue)
o3Value = pd.Series(o3Value)
no2Value = pd.Series(no2Value)

df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})

# %%
def test(sidoName):
  URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'
      'getCtprvnMesureSidoLIst?'
      'sidoName='+sidoName+
      '&searchCondition=hour'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
  
  response = requests.get(URL)
  r = response.json()
  items = r['response']['body']['items']
  # 리스트로 모든 것들이 있다.

  cityName = [item['cityName'] for item in items]
  pm10Value = [item['pm10Value'] for item in items]
  pm25Value = [item['pm25Value'] for item in items]
  so2Value = [item['so2Value'] for item in items]
  coValue = [item['coValue'] for item in items]
  o3Value = [item['o3Value'] for item in items]
  no2Value = [item['no2Value'] for item in items]

  pd_cityName = pd.Series(cityName)
  pd_pm10Value = pd.Series(pm10Value)   
  pd_pm25Value = pd.Series(pm25Value)
  so2Value = pd.Series(so2Value)
  coValue = pd.Series(coValue)
  o3Value = pd.Series(o3Value)
  no2Value = pd.Series(no2Value)

  df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})
  return df

  # 데이터 프레임을 만들 것이다. 알아야하는 것은 list의 list ㅋ 프리헨션 이용

# %%
iface = gr.Interface(test, gr.inputs.Dropdown(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종']), outputs=['dataframe'])
iface.launch(debug=True)

# iface를 사용하면 이렇게 된다는 것이다. 여기보면. 
# 그라디오 이쁘게 해준다. 
# 또 하나는 다음 시간에 할 것. 일종의 인풋 아웃풋 펑션으로 되어 있다. 펑션의 형태이다.
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://49874.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://49874.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
